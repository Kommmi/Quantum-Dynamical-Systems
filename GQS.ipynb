# %% [markdown]
# <a href="https://colab.research.google.com/github/Kommmi/Quantum-Dynamical-Systems/blob/main/GQS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf Quantum-Dynamical-Systems
# !git clone https://github.com/Kommmi/Quantum-Dynamical-Systems.git

# Move into the repo
# %cd Quantum-Dynamical-Systems

# Install dependencies
# !pip install -r requirements.txt

# Install the package in editable mode
# !pip install -e .

from IPython.display import clear_output
clear_output()

from gqs.states import Initial_state
from gqs.dynamics import Hamiltonian_QK, floquet_operator_from_H
from gqs.distances import Quantum_EMD
from gqs.gqs import GQS_Bloch_Sphere_chi

print("Module ready to go :)")
# Out:
# Module ready to go :)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nqubit = 4
site_a = 0
theta, phi = 0.8, 0.2
eps = 1e-2
theta_p, phi_p = theta + eps, phi

# Kicked-top parameters
kappa = 3.0
j = nqubit / 2
tau = 1.0
T = 25  # number of kicks / discrete steps

psi0 = Initial_state(nqubit, theta, phi)
psi0_p = Initial_state(nqubit, theta_p, phi_p)

print("State shapes:", psi0.shape, psi0_p.shape)
print("Norms:", np.vdot(psi0, psi0).real, np.vdot(psi0_p, psi0_p).real)
# Out:
# State shapes: (16,) (16,)
# Norms: 1.0000000000000002 0.9999999999999994

# %% [markdown]
# First, use the `git clone` command to download your repository. Replace `YOUR_GITHUB_REPO_URL` with the actual URL of your GitHub repository.

# %%
# !git clone YOUR_GITHUB_REPO_URL

# %% [markdown]
# After cloning, you can list the contents of your current directory to see the newly cloned repository folder.

# %%
# !ls

# %% [markdown]
# Once cloned, you can navigate into the repository folder and work with your code as usual. For example, to change into the repository directory (assuming its name is `my-repo`), you would use:

# %%
# %cd my-repo
# !ls

# %% [markdown]
# The `os` module provides a way of using operating system dependent functionality. It lets you interact with the underlying operating system by providing functions to deal with file paths, directory listings, process management, and more.

# %%
import os

# Get the current working directory
print(f"Current working directory: {os.getcwd()}")

# List contents of the current directory
print(f"\nContents of current directory: {os.listdir('.')}")

# Create a new directory
new_dir = 'my_new_directory'
if not os.path.exists(new_dir):
    os.makedirs(new_dir)
    print(f"\nCreated directory: {new_dir}")
else:
    print(f"\nDirectory '{new_dir}' already exists.")

# Change the current working directory
# os.chdir(new_dir)
# print(f"Changed to directory: {os.getcwd()}")

# Get environment variables
print(f"\nPATH environment variable: {os.environ.get('PATH')}")

# Remove a directory (only if empty)
# os.rmdir(new_dir)
# print(f"\nRemoved directory: {new_dir}")

# Path manipulation
file_path = os.path.join(os.getcwd(), 'my_new_file.txt')
print(f"\nConstructed file path: {file_path}")
print(f"Base name of path: {os.path.basename(file_path)}")
print(f"Directory name of path: {os.path.dirname(file_path)}")
print(f"Is it a directory? {os.path.isdir(file_path)}")
print(f"Does it exist? {os.path.exists(file_path)}")

# %% [markdown]
# The `sys` module provides access to system-specific parameters and functions. It allows you to interact with the Python interpreter itself, such as accessing command-line arguments, standard input/output streams, and information about the Python environment.

# %%
import sys

# Get command-line arguments (usually empty in notebooks unless run from command line with args)
print(f"Command-line arguments: {sys.argv}")

# Get Python version information
print(f"\nPython version: {sys.version}")
print(f"Python version info: {sys.version_info}")

# Get the list of directories where Python searches for modules
print(f"\nPython module search paths (sys.path):\n")
for p in sys.path:
    print(p)

# Get maximum integer value (Python 2 compatibility, less relevant in Python 3)
# print(f"\nMax integer value: {sys.maxint}")

# Exit the interpreter (use with caution, will stop the kernel)
# sys.exit("Exiting Python interpreter")

# Get standard input/output/error streams
print(f"\nStandard output stream: {sys.stdout}")
print(f"Standard error stream: {sys.stderr}")
